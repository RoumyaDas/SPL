# %%
import pandas as pd
import glob
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/*.csv")]

bbl = pd.concat(l, axis = 0)
bbl['start_date'] = pd.to_datetime(bbl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

bbl['year'] = bbl.start_date.apply(year_int)

bbl = bbl[bbl.year>=2020]

print(bbl.shape)
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1443068_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1443069_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/571251_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/571250_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1152531_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1386097_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1152530_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/654067_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/897739_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1269677_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bbl_male_csv2/1269676_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/*.csv")]

cpl = pd.concat(l, axis = 0)
cpl['start_date'] = pd.to_datetime(cpl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

cpl['year'] = cpl.start_date.apply(year_int)

cpl = cpl[cpl.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/635215_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1227872_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1227873_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/743173_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1185852_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/857723_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1369577_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1185853_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1369576_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1094697_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/cpl_male_csv2/1094696_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/*.csv")]

ctc = pd.concat(l, axis = 0)
ctc['start_date'] = pd.to_datetime(ctc['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

ctc['year'] = ctc.start_date.apply(year_int)

ctc = ctc[ctc.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/851969_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/530354_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/530355_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/575157_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1299615_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1299614_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1444793_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1157256_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1444792_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1003871_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ctc_male_csv2/1334895_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/*.csv")]

ilt = pd.concat(l, axis = 0)
ilt['start_date'] = pd.to_datetime(ilt['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

ilt['year'] = ilt.start_date.apply(year_int)

ilt = ilt[ilt.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1346949_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1346948_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1406889_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1406912_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1406913_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1406918_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1406919_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1462194_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1462195_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1346943_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ilt_male_csv2/1346942_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/*.csv")]

ipl = pd.concat(l, axis = 0)
ipl['start_date'] = pd.to_datetime(ipl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

ipl['year'] = ipl.start_date.apply(year_int)

ipl = ipl[ipl.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/729305_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/1473497_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/1359495_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/1359494_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/392199_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/392198_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/734021_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/336010_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/336011_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/1254117_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipl_male_csv2/501251_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/*.csv")]

lpl = pd.concat(l, axis = 0)
lpl['start_date'] = pd.to_datetime(lpl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

lpl['year'] = lpl.start_date.apply(year_int)

lpl = lpl[lpl.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1324525_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1324524_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1238764_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1238765_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1291209_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1291208_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1428480_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1428481_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1428465_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1428464_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/lpl_male_csv2/1291203_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/*.csv")]

mlc = pd.concat(l, axis = 0)
mlc['start_date'] = pd.to_datetime(mlc['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

mlc['year'] = mlc.start_date.apply(year_int)

mlc = mlc[mlc.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1381379_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1381378_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1381373_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1381372_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1432738_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1432739_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1432732_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1432733_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1381364_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1381365_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/mlc_male_csv2/1432745_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/*.csv")]

ntb = pd.concat(l, axis = 0)
ntb['start_date'] = pd.to_datetime(ntb['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

ntb['year'] = ntb.start_date.apply(year_int)

ntb = ntb[ntb.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1297868_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1127565_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1297869_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1127564_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/804601_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/804467_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1410457_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1410456_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/693209_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/1347577_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ntb_male_csv2/947231_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/*.csv")]

psl = pd.concat(l, axis = 0)
psl['start_date'] = pd.to_datetime(psl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

psl['year'] = psl.start_date.apply(year_int)

psl = psl[psl.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1354927_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1354926_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1475258_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1475259_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1168832_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1168833_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1293017_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1293016_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/959201_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1416479_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/psl_male_csv2/1416478_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/*.csv")]

sat = pd.concat(l, axis = 0)
sat['start_date'] = pd.to_datetime(sat['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

sat['year'] = sat.start_date.apply(year_int)

sat = sat[sat.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1343954_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1343955_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1449654_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1449655_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1449660_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1449661_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1392675_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1392674_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1343960_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1343961_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sat_male_csv2/1343943_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/*.csv")]

sma = pd.concat(l, axis = 0)
sma['start_date'] = pd.to_datetime(sma['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

sma['year'] = sma.start_date.apply(year_int)

sma = sma[sma.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1244382_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1205741_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1244383_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1383504_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1157139_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1157138_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1244310_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1244311_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1332920_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1175027_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/sma_male_csv2/1157170_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/*.csv")]

ssm = pd.concat(l, axis = 0)
ssm['start_date'] = pd.to_datetime(ssm['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

ssm['year'] = ssm.start_date.apply(year_int)

ssm = ssm[ssm.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1409474_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1409475_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1341222_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1341223_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1197750_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1341197_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1197751_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1341196_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1118538_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1289603_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ssm_male_csv2/1234009_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/*.csv")]

bpl = pd.concat(l, axis = 0)
bpl['start_date'] = pd.to_datetime(bpl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

bpl['year'] = bpl.start_date.apply(year_int)

bpl = bpl[bpl.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/551067_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/551066_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/935337_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1459565_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1459564_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/599887_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1121279_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1208082_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1208083_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1121278_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/bpl_male_csv2/1351089_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/*.csv")]

npl = pd.concat(l, axis = 0)
npl['start_date'] = pd.to_datetime(npl['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

npl['year'] = npl.start_date.apply(year_int)

npl = npl[npl.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462649_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462648_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462643_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462642_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462660_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462661_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462596_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462654_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462655_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462667_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/npl_male_csv2/1462666_info.csv
# ...

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/*.csv")]

ipt = pd.concat(l, axis = 0)
ipt['start_date'] = pd.to_datetime(ipt['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

ipt['year'] = ipt.start_date.apply(year_int)

ipt = ipt[ipt.year>=2020]
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1375549_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1305441_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1305440_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1305436_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1305437_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1375543_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1375542_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1227505_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1430831_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1430830_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/ipt_male_csv2/1089611_info.csv
# ...

# %%
leagues = [bbl,cpl,ctc,ilt,ipl,lpl,mlc,ntb,psl,sat,sma,ssm,bpl,npl,ipt]

df_t20 = bbl

for df in leagues[1:]:
    df_t20 = pd.concat([df_t20,df], axis=0)
    
df_t20 = df_t20.drop_duplicates().reset_index(drop=True)

print(df_t20.shape)
# Out:
# (679363, 23)

# %%
l = [pd.read_csv(filename) if "_info" not in filename else print(filename) for filename\
     in glob.glob("/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/*.csv")]

t20s = pd.concat(l, axis = 0)
t20s['start_date'] = pd.to_datetime(t20s['start_date'])

def year_int(value):
    output = int(str(value)[:4])
    return output

t20s['year'] = t20s.start_date.apply(year_int)

t20s = t20s[t20s.year>=2020]

print(t20s.shape)
# Out:
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/534234_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1273726_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1271447_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1273727_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1271446_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/534235_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/954737_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1459384_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1412550_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1233973_info.csv
# /Users/roumyadas/Desktop/Data/t20_cricket_data/Data/t20s_male_csv2/1459385_info.csv
# ...

# %%
df_t20 = df_t20[df_t20.start_date<='2025-06-03']
t20s = t20s[t20s.start_date<='2025-06-03']

# %%
df_t20.to_csv('/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/created_data/t20s_2020_onwards.csv',
             index=None)

# %%
t20s.to_csv('/Users/roumyadas/Desktop/Data/t20_cricket_data/Data/created_data/t20is_2020_onwards.csv',
             index=None)
